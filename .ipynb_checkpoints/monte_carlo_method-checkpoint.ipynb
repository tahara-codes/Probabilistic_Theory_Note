# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
def x(k): return random.random()
def y(k): return random.random()

# %%
P = 1000
R = []
for k in range(P):
      R.append([x(k),y(k)])
x, y = zip(*R)

# %%
plt.scatter(x, y)
plt.show()

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

total_num = 10000
dice_mean = 0.0
count = 0
mean_history = np.zeros(total_num)

for i in range(total_num):
    count += 1
    prob = random.randint(1, 6)
    dice_mean += (prob - dice_mean) / count
    mean_history[i] = dice_mean

print(f'平均値: {dice_mean}')

plt.scatter(x=range(total_num), y=mean_history, color='#DE3838', alpha=0.3, s=15)
plt.xlabel('trials')
plt.ylabel('mean')
plt.show()
# Out:
# 平均値: 3.4736999999999827
